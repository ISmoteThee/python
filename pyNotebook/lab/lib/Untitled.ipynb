# %%
import pandas as pd

# %%
import altair as alt

# %%
my_list = [1,3,5,7,9,11,99,999, 9999]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 11133

# %%
my_series.max()
# Out:
# 9999

# %%
my_series.min()
# Out:
# 1

# %%
my_series.mean()
# Out:
# 1237.0

# %%
my_series.median()
# Out:
# 9.0

# %%
my_series.std()
# Out:
# 3301.82843285353

# %%
my_series.describe()
# Out:
# count       9.000000
# mean     1237.000000
# std      3301.828433
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        99.000000
# max      9999.000000
# dtype: float64

# %%
committee_list = pd.read_csv("/Users/motes/python/pyNotebook/committees.csv")

# %%
committee_list.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
committee_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ocd_prop_id             102 non-null    object
#  1   calaccess_prop_id       102 non-null    int64
#  2   ccdc_prop_id            102 non-null    int64
#  3   prop_name               102 non-null    object
#  4   ccdc_committee_id       102 non-null    int64
#  5   calaccess_committee_id  102 non-null    int64
#  6   committee_name          102 non-null    object
#  7   committee_position      102 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 6.5+ KB

# %%
contrib_list = pd.read_csv("/Users/motes/python/pyNotebook/contributions.csv")

# %%
contrib_list.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contrib_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   calaccess_committee_id        56379 non-null  int64
#  1   committee_name                56379 non-null  object
#  2   calaccess_filing_id           56379 non-null  int64
#  3   date_received                 56379 non-null  object
#  4   contributor_lastname          56375 non-null  object
#  5   contributor_firstname         53411 non-null  object
#  6   contributor_city              56369 non-null  object
#  7   contributor_state             56363 non-null  object
#  8   contributor_zip               56366 non-null  object
#  9   contributor_employer          48572 non-null  object
#  10  contributor_occupation        53273 non-null  object
#  11  contributor_is_self_employed  56379 non-null  bool
# ...

# %%
committee_list.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#                              ...
# 97     PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 98     PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 99     PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 100    PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 101    PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# Name: prop_name, Length: 102, dtype: object

# %%
committee_list.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
my_prop = "PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE."

# %%
my_committees = committee_list[committee_list.prop_name == my_prop]

# %%
my_committees.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
my_committees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ocd_prop_id             11 non-null     object
#  1   calaccess_prop_id       11 non-null     int64
#  2   ccdc_prop_id            11 non-null     int64
#  3   prop_name               11 non-null     object
#  4   ccdc_committee_id       11 non-null     int64
#  5   calaccess_committee_id  11 non-null     int64
#  6   committee_name          11 non-null     object
#  7   committee_position      11 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
contrib_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   calaccess_committee_id        56379 non-null  int64
#  1   committee_name                56379 non-null  object
#  2   calaccess_filing_id           56379 non-null  int64
#  3   date_received                 56379 non-null  object
#  4   contributor_lastname          56375 non-null  object
#  5   contributor_firstname         53411 non-null  object
#  6   contributor_city              56369 non-null  object
#  7   contributor_state             56363 non-null  object
#  8   contributor_zip               56366 non-null  object
#  9   contributor_employer          48572 non-null  object
#  10  contributor_occupation        53273 non-null  object
#  11  contributor_is_self_employed  56379 non-null  bool
# ...

# %%
merged = pd.merge(my_committees, contrib_list, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ocd_prop_id                   860 non-null    object
#  1   calaccess_prop_id             860 non-null    int64
#  2   ccdc_prop_id                  860 non-null    int64
#  3   prop_name                     860 non-null    object
#  4   ccdc_committee_id             860 non-null    int64
#  5   calaccess_committee_id        860 non-null    int64
#  6   committee_name_x              860 non-null    object
#  7   committee_position            860 non-null    object
#  8   committee_name_y              860 non-null    object
#  9   calaccess_filing_id           860 non-null    int64
#  10  date_received                 860 non-null    object
#  11  contributor_lastname          860 non-null    object
# ...

# %%
merged.amount.sum()
# Out:
# 35177017.64

# %%
merged.committee_position
# Out:
# 0      SUPPORT
# 1      SUPPORT
# 2      SUPPORT
# 3      SUPPORT
# 4      SUPPORT
#         ...
# 855    SUPPORT
# 856     OPPOSE
# 857     OPPOSE
# 858     OPPOSE
# 859     OPPOSE
# Name: committee_position, Length: 860, dtype: object

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    762
# OPPOSE      98
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
support.amount.sum()
# Out:
# 32675806.0

# %%
oppose.amount.sum()
# Out:
# 2501211.64

# %%
support.amount.sum()/merged.amount.sum()*100
# Out:
# 92.88964270479867

# %%
merged.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 142            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 79             83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 846            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 851            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 852            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 142                456                 1381808
# ...

# %%
support.sort_values('amount', ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 142            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 79             83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 851            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 846            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 852            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 142                456                 1381808
# ...

# %%
oppose.sort_values('amount', ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 840  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 839            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 312            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 310            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 308            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 840            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 839                463                 1387789
# ...

# %%
merged.groupby("contributor_state").amount.sum().reset_index()
# Out:
#    contributor_state       amount
# 0                 AB         0.00
# 1                 AL       100.00
# 2                 AZ       500.00
# 3                 BC         0.00
# 4                 CA  17491193.00
# 5                 CO     39300.00
# 6                 CT       100.00
# 7                 DC   2618600.00
# 8                 DE   6140100.00
# 9                 FL   1250850.00
# 10                GA       100.00
# 11                ID      1000.00
# 12                IL      7000.00
# 13                LA       100.00
# 14                MA       600.00
# 15                MD      2971.00
# 16                MI       400.00
# 17                MO       550.00
# 18                NC       200.00
# 19                NV      1800.00
# 20                NY   5446985.00
# 21                OH      2950.00
# 22                OK       200.00
# 23                OR      1400.00
# 24                PA   1215475.00
# 25                RI      6700.00
# ...

# %%
merged[merged.contributor_state == 'AL']
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 368  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 368            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 368                460                 1371855
#
#                                       committee_name_x committee_position  \
# 368  MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64            SUPPORT
#
#                                       committee_name_y  calaccess_filing_id  \
# 368  MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64              2060277
#
#     date_received contributor_lastname contributor_firstname contributor_city  \
# 368    2016-06-17              WHIDDON                   LES         NEWVILLE
#
#     contributor_state contributor_zip contributor_employer  \
# ...

# %%
merged[merged.contributor_state == 'GA']
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 549  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 549            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 549                461                 1343793
#
#                                       committee_name_x committee_position  \
# 549  CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...            SUPPORT
#
#                                       committee_name_y  calaccess_filing_id  \
# 549  CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...              2063970
#
#     date_received contributor_lastname contributor_firstname contributor_city  \
# 549    2016-06-19               KAISER                 DAVID          ATLANTA
#
#     contributor_state contributor_zip contributor_employer  \
# ...

# %%
merged.groupby("contributor_state").amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#    contributor_state       amount
# 4                 CA  17491193.00
# 8                 DE   6140100.00
# 20                NY   5446985.00
# 7                 DC   2618600.00
# 9                 FL   1250850.00
# 24                PA   1215475.00
# 27                VA    895243.64
# 28                WA     50800.00
# 5                 CO     39300.00
# 12                IL      7000.00
# 25                RI      6700.00
# 15                MD      2971.00
# 21                OH      2950.00
# 26                TX      1800.00
# 19                NV      1800.00
# 23                OR      1400.00
# 11                ID      1000.00
# 14                MA       600.00
# 17                MO       550.00
# 2                 AZ       500.00
# 16                MI       400.00
# 18                NC       200.00
# 22                OK       200.00
# 1                 AL       100.00
# 13                LA       100.00
# 10                GA       100.00
# ...

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 482                  SEAN                          PARKER            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 108                DANIEL                           LEWIS            SUPPORT
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# ..                    ...                             ...                ...
# 430                  RICH                        GOLDBERG            SUPPORT
# 358               MARSTON                         MEDLOCK            SUPPORT
# 497             STEPHANIE                 WARREN-SAMARIPA            SUPPORT
# 16             AMIRGHASEM                 SAMIMI-ARDESTAN            SUPPORT
# 136                 DAVID                            WOOD            SUPPORT
#
#         amount
# 483  7250000.0
# ...

# %%
support.fillna("__Blank__").groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending = False).head()
# Out:
#     contributor_firstname                               contributor_lastname  \
# 444                  SEAN                     PARKER AND AFFILIATED ENTITIES
# 526             __Blank__                             FUND FOR POLICY REFORM
# 527             __Blank__      FUND FOR POLICY REFORM (NONPROFIT 501 (C)(4))
# 519             __Blank__  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...
# 538             __Blank__                             NEW APPROACH PAC (MPO)
#
#     committee_position     amount
# 444            SUPPORT  7250000.0
# 526            SUPPORT  6140000.0
# 527            SUPPORT  3940000.0
# 519            SUPPORT  3000000.0
# 538            SUPPORT  2615000.0

# %%
oppose.fillna("__Blank__").groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending = False).head()
# Out:
#    contributor_firstname                               contributor_lastname  \
# 20                 JULIE                                            SCHAUER
# 66             __Blank__                                   SAM ACTION, INC.
# 52             __Blank__  CALIFORNIANS FOR JOBS, ASSEMBLYMEMBER JIM COOP...
# 51             __Blank__  CALIF. TEAMSTERS PUBLIC AFFAIRS COUNCIL ISSUES...
# 45             __Blank__                 CALIF. ASSOC. OF HIGHWAY PATROLMEN
#
#    committee_position     amount
# 20             OPPOSE  1364000.0
# 66             OPPOSE   889650.0
# 52             OPPOSE    25000.0
# 51             OPPOSE    25000.0
# 45             OPPOSE    25000.0

# %%
merged.fillna("==NULL==").sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 142            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 79             83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 846            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 851            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 852            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 142                456                 1381808
# ...

# %%
oppose.groupby(["contributor_employer"]).amount.sum().reset_index().sort_values("amount", ascending = False).head()
# Out:
#    contributor_employer  amount
# 17                   CS  6500.0
# 18                  CSI  5000.0
# 4     BOSTON SCIENTIFIC  1550.0
# 23                 NONE  1500.0
# 25              RETIRED  1371.0

# %%
support.groupby(["contributor_employer"]).amount.sum().reset_index().sort_values("amount", ascending = False).head()
# Out:
#           contributor_employer     amount
# 322     SEAN PARKER FOUNDATION  1250000.0
# 294                    RETIRED   502300.0
# 351  TAO CAPITAL PARTNERS, LLC   450000.0
# 350   TAO CAPITAL PARTNERS LLC   450000.0
# 361         THIEL CAPITAL, LLC   300000.0

# %%
merged.calaccess_committee_id.value_counts()
# Out:
# 1343793    420
# 1381808    250
# 1382568     88
# 1371855     40
# 1386560     26
# 1382525      9
# 1385745      8
# 1385506      7
# 1387789      6
# 1390962      4
# 1376077      2
# Name: calaccess_committee_id, dtype: int64

# %%
merged.calaccess_committee_id
# Out:
# 0      1381808
# 1      1381808
# 2      1381808
# 3      1381808
# 4      1381808
#         ...
# 855    1385745
# 856    1390962
# 857    1390962
# 858    1390962
# 859    1390962
# Name: calaccess_committee_id, Length: 860, dtype: int64

# %%
top_supporters = support.fillna("==NULL==").groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(20)

# %%
top_supporters.head(10)
# Out:
#     contributor_firstname                               contributor_lastname  \
# 487                  SEAN                     PARKER AND AFFILIATED ENTITIES
# 19               ==NULL==                             FUND FOR POLICY REFORM
# 20               ==NULL==      FUND FOR POLICY REFORM (NONPROFIT 501 (C)(4))
# 12               ==NULL==  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...
# 31               ==NULL==                             NEW APPROACH PAC (MPO)
# 486                  SEAN                                             PARKER
# 145                DANIEL                                              LEWIS
# 223                 HENRY                                      VAN AMERINGEN
# 11               ==NULL==                                 DRUG POLICY ACTION
# 417              NICHOLAS                                           PRITZKER
#
#         amount
# 487  7250000.0
# 19   6140000.0
# 20   3940000.0
# 12   3000000.0
# 31   2615000.0
# 486  1500000.0
# ...

# %%
alt.Chart(top_supporters.head(10)).mark_bar().encode(
    x="amount",
    y="contributor_lastname"
)
# Out:
# alt.Chart(...)

# %%
top_supporters["contributor_fullname"] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters.contributor_fullname
# Out:
# 487                  SEAN PARKER AND AFFILIATED ENTITIES
# 19                       ==NULL== FUND FOR POLICY REFORM
# 20     ==NULL== FUND FOR POLICY REFORM (NONPROFIT 501...
# 12     ==NULL== DRUG POLICY ACTION - NON PROFIT 501C4...
# 31                       ==NULL== NEW APPROACH PAC (MPO)
# 486                                          SEAN PARKER
# 145                                         DANIEL LEWIS
# 223                                  HENRY VAN AMERINGEN
# 11                           ==NULL== DRUG POLICY ACTION
# 417                                    NICHOLAS PRITZKER
# 21     ==NULL== GHOST MANAGEMENT GROUP, LLC DBA WEEDMAPS
# 3      ==NULL== CALIFORNIANS FOR SENSIBLE REFORM, SPO...
# 14     ==NULL== DRUG POLICY ACTION - NON-PROFIT 501C4...
# 2      ==NULL== CALIFORNIANS FOR RESPONSIBLE MARIJUAN...
# 433                                          PETER THIEL
# 13        ==NULL== DRUG POLICY ACTION - NON-PROFIT 501C4
# ...

# %%
alt.Chart(top_supporters.head(10)).mark_bar().encode(
    x="amount",
    y=alt.Y("contributor_fullname", sort='-x')
).properties(title="Top Contributors to the Dope")
# Out:
# alt.Chart(...)

# %%
top_contributors = merged.fillna("").groupby(
    ["contributor_firstname", "contributor_lastname", "committee_position"]
).amount.sum().reset_index().sort_values("amount", ascending=False).head(50)

# %%
top_contributors["contributor_fullname"] = top_contributors["contributor_firstname"] + " " + top_contributors["contributor_lastname"]

# %%
alt.Chart(top_contributors.head(20)).mark_bar().encode(
    x="amount",
    y=alt.Y("contributor_fullname",sort="-x"),
    color="committee_position"
)
# Out:
# alt.Chart(...)

# %%
top_supporters.head(20).to_csv("top_supporters.csv")
